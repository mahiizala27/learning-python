# %% [markdown]
# <a href="https://colab.research.google.com/github/mahiizala27/learning-python/blob/main/append.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python append() LIST METHOD

# %%
list1=[1,2,3]

# %%
list1
# Out:
# [1, 2, 3]

# %%
list1.append(4)

# %%
list1
# Out:
# [1, 2, 3, 4]
